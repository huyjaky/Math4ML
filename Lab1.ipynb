# %% [markdown]
# # Lab 1
# ## Tên: Phan Đức Huy, Mã SV: 22AD021

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
last_id = 14

# %% [markdown]
# #### Câu 1

# %%
x = []
for i in range(10):
  x.append(np.random.randint(-last_id, last_id))
print(x)
# Out:
# [-8, 6, 13, 6, 8, -2, -1, -6, 3, 7]

# %% [markdown]
# #### Câu 2

# %%
x = np.sort(x)
print(x)
# Out:
# [-8 -6 -2 -1  3  6  6  7  8 13]

# %% [markdown]
# #### Câu 3

# %%
A = 2*x + 1
B = x**2

plt.plot(x, A, 'r', label="2*x + 1")
plt.plot(x, B, 'b', label="x**2")
plt.legend()
plt.show()
